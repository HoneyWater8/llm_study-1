# %%
import enum

class OPENAI_LLMs(enum.Enum):
  gpt_4o_mini = (enum.auto(), "gpt-4o-mini") 
  gpt_4o = (enum.auto(), "gpt-4o") 
  gpt_4o1 = (enum.auto(), "gpt-4o1")

# %%
llm_name = "gpt_4o_mini"

# %%
list(OPENAI_LLMs.__members__)
# Out:
# ['gpt_4o_mini', 'gpt_4o']

# %%
for member in OPENAI_LLMs.__members__:
  print(member)
# Out:
# gpt_4o_mini
# gpt_4o

# %%
if llm_name not in OPENAI_LLMs.__members__:
  print("어서와~")

# %%
OPENAI_LLMs[llm_name].name
# Out:
# 'gpt_4o_mini'

# %%
import requests

url = "https://huggingface.co/api/models"

result = requests.get(url)

# %%
import json 

lst = json.loads(result.text)

# %%
len(lst)
# Out:
# 1000

# %% [markdown]
# # [올라마 설치](https://ollama.com/download/windows)

# %% [markdown]
# # [올라마 예제](https://velog.io/@boyunj0226/%EB%A1%9C%EC%BB%AC%EC%97%90%EC%84%9C-llm-%EC%B1%97%EB%B4%87-%ED%8E%98%EC%9D%B4%EC%A7%80-%EB%A7%8C%EB%93%A4%EA%B8%B0-Ollama-streamlit)

# %%
# from langchain_community.chat_models import ChatOllama
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
import time

# Ollama 모델을 불러옵니다.
llm = ChatOllama(model="gemma3:1b")

# 프롬프트
chat_prompt = ChatPromptTemplate.from_messages([
    ("assistant", "너는 도움을 주는 어시스턴트야."),
    ("user", "{user_input}"),
])

# 체인 생성
chain = chat_prompt | llm | StrOutputParser()
# 모델 답변 
gen = chain.stream({"user_input": "일본사람들에게 한국음식 3가지 추천해줘."})
# 모델 답변 프린트
for token in gen:
    # 스트림에서 받은 데이터의 내용을 출력합니다. 줄바꿈 없이 이어서 출력하고, 버퍼를 즉시 비웁니다.
    print(token, end="", flush=True)
    time.sleep(0.05)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_12000\2442709141.py:7: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   llm = ChatOllama(model="gemma3:1b")
# 네, 일본인 분들께 추천할 만한 한국 음식 3가지입니다.
#
# 1.  **김치:** 한국의 대표적인 발효 음식으로, 배추, 무 등을 이용하여 만드는 맛있는 김치는 일본인들에게도 인기가 많습니다.
#     *   **추천 이유:** 밥반찬으로 먹거나, 찌개나 국밥에 넣어 먹으면 맛있습니다. 매콤한 맛이 일상적인 일본인들의 입맛에 잘 맞습니다.
#     *   **팁:** 묵은지를 사용하여 깊은 맛을 내는 것이 중요합니다.
#
# 2.  **불고기:** 부드러운 고기를 간장 양념에 재워 구워 먹는 불고기는 일본인들에게도 사랑받는 메뉴입니다.
#     *   **추천 이유:** 얇게 썬 고기는 밥과 함께 먹으면 맛있고, 찌개나 국밥에 넣어 먹어도 좋습니다.
#     *   **팁:** 고기를 너무 오래 굽지 않도록 주의해야 합니다.
#
# 3.  **비빔국수:** 맑은 국물에 소금을 약간 넣고 تقلی́د (take-ryu) 비빔장을 넣어 먹는 비빔국수도 일본인들에게 인기 있는 음식입니다.
#     *   **추천 이유:** 깔끔하고 시원한 맛으로, 밥과 함께 먹으면 든든하게 먹을 수 있습니다.
#     *   **팁:** 비빔장을 너무 많이 넣으면 너무 짜게 느껴질 수 있으니 주의해야 합니다.
#
# 이 외에도 떡볶이, 갈비찜, 삼겹살 등 다양한 한국 음식이 일본인들에게 널리 사랑받고 있습니다. 😊
#
# 혹시 특별히 어떤 맛이나 특징을 선호하시나요?  (예: 매운 음식, 달콤한 음식, 퓨전 음식 등)

# %% [markdown]
# # [올라마 다른 예제](https://fornewchallenge.tistory.com/entry/Ollama-Langchain-Streamlit%EC%9C%BC%EB%A1%9C-%EB%8C%80%EA%B7%9C%EB%AA%A8-%EC%96%B8%EC%96%B4-%EB%AA%A8%EB%8D%B8-%EA%B8%B0%EB%B0%98-PDF-%EC%B1%97%EB%B4%87-%EB%A7%8C%EB%93%A4%EA%B8%B0)

# %%
tmp = {"a":"a1", "b":"b1"}
tuple(tmp.values())
# Out:
# ('a1', 'b1')

# %%
def ask(question, message_history=[], model="gpt-3.5-turbo"):
    if len(message_history) == 0:
        # 최초 질문
        message_history.append(
            {
                "role": "system",
                "content": "You are a helpful assistant. You must answer in Korean.",
            }
        )

    # 사용자 질문 추가
    message_history.append(
        {
            "role": "user",
            "content": question,
        },
    )

    # GPT에 질문을 전달하여 답변을 생성
    completion = client.chat.completions.create(
        model=model,
        messages=message_history,
    )

    # 사용자 질문에 대한 답변을 추가
    message_history.append(
        {"role": "assistant", "content": completion.choices[0].message.content}
    )

    return message_history

# %%
[("a", "b")] + [("c", "d")]
# Out:
# [('a', 'b'), ('c', 'd')]
